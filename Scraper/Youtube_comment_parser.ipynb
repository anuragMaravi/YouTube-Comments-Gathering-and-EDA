# %% [markdown]
# # Download Comments from Youtube videos
#
# GitHub Repo : [youtube-comment-scraper](https://github.com/ahmedshahriar/youtube-comment-scraper)

# %%
import pandas as pd
import json
import os
import sys
import re
import time

import requests

# pandas dataframe display configuration
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

YOUTUBE_COMMENTS_AJAX_URL = 'https://www.youtube.com/comment_service_ajax'

USER_AGENT = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36'
# csv file name
FILE_NAME = 'ytb_comments.csv'

# set parameters
# filter comments by popularity or recent, 0:False, 1:True
SORT_BY_POPULAR = 1
# default recent
SORT_BY_RECENT = 1
# set comment limit
COMMENT_LIMIT = 100

YT_CFG_RE = r'ytcfg\.set\s*\(\s*({.+?})\s*\)\s*;'
YT_INITIAL_DATA_RE = r'(?:window\s*\[\s*["\']ytInitialData["\']\s*\]|ytInitialData)\s*=\s*({.+?})\s*;\s*(?:var\s+meta|</script|\n)'


def regex_search(text, pattern, group=1, default=None):
    match = re.search(pattern, text)
    return match.group(group) if match else default


def ajax_request(session, endpoint, ytcfg, retries=5, sleep=20):
    url = 'https://www.youtube.com' + endpoint['commandMetadata']['webCommandMetadata']['apiUrl']
    
    data = {'context': ytcfg['INNERTUBE_CONTEXT'],
            'continuation': endpoint['continuationCommand']['token']}

    for _ in range(retries):
        response = session.post(url, params={'key': ytcfg['INNERTUBE_API_KEY']}, json=data)
        if response.status_code == 200:
            return response.json()
        if response.status_code in [403, 413]:
            return {}
        else:
            time.sleep(sleep)


def download_comments(YOUTUBE_VIDEO_URL, sort_by=SORT_BY_RECENT, language=None, sleep=0.1):
    session = requests.Session()
    session.headers['User-Agent'] = USER_AGENT
    response = session.get(YOUTUBE_VIDEO_URL)

    if 'uxe=' in response.request.url:
        session.cookies.set('CONSENT', 'YES+cb', domain='.youtube.com')
        response = session.get(YOUTUBE_VIDEO_URL)

    html = response.text
    ytcfg = json.loads(regex_search(html, YT_CFG_RE, default=''))
    if not ytcfg:
        return # Unable to extract configuration
    if language:
        ytcfg['INNERTUBE_CONTEXT']['client']['hl'] = language

    data = json.loads(regex_search(html, YT_INITIAL_DATA_RE, default=''))

    section = next(search_dict(data, 'itemSectionRenderer'), None)
    renderer = next(search_dict(section, 'continuationItemRenderer'), None) if section else None
    if not renderer:
        # Comments disabled?
        return

    needs_sorting = sort_by != SORT_BY_POPULAR
    continuations = [renderer['continuationEndpoint']]
    while continuations:
        continuation = continuations.pop()
        response = ajax_request(session, continuation, ytcfg)

        if not response:
            break
        if list(search_dict(response, 'externalErrorMessage')):
            raise RuntimeError('Error returned from server: ' + next(search_dict(response, 'externalErrorMessage')))

        if needs_sorting:
            sort_menu = next(search_dict(response, 'sortFilterSubMenuRenderer'), {}).get('subMenuItems', [])
            if sort_by < len(sort_menu):
                continuations = [sort_menu[sort_by]['serviceEndpoint']]
                needs_sorting = False
                continue
            raise RuntimeError('Failed to set sorting')

        actions = list(search_dict(response, 'reloadContinuationItemsCommand')) + \
                  list(search_dict(response, 'appendContinuationItemsAction'))
        for action in actions:
            for item in action.get('continuationItems', []):
                if action['targetId'] == 'comments-section':
                    # Process continuations for comments and replies.
                    continuations[:0] = [ep for ep in search_dict(item, 'continuationEndpoint')]
                if action['targetId'].startswith('comment-replies-item') and 'continuationItemRenderer' in item:
                    # Process the 'Show more replies' button
                    continuations.append(next(search_dict(item, 'buttonRenderer'))['command'])

        for comment in reversed(list(search_dict(response, 'commentRenderer'))):
            comment_content = ''.join([c['text'] for c in comment['contentText'].get('runs', [])])
            stripped_comment = comment_content.replace('\n', ' ')
            yield {'cid': comment['commentId'],
                   'text': stripped_comment,
                   'time': comment['publishedTimeText']['runs'][0]['text'],
                   'author': comment.get('authorText', {}).get('simpleText', ''),
                   'channel': comment['authorEndpoint']['browseEndpoint'].get('browseId', ''),
                   'votes': comment.get('voteCount', {}).get('simpleText', '0'),
                   'photo': comment['authorThumbnail']['thumbnails'][-1]['url'],
                   'heart': next(search_dict(comment, 'isHearted'), False)}

        time.sleep(sleep)


def search_dict(partial, search_key):
    stack = [partial]
    while stack:
        current_item = stack.pop()
        if isinstance(current_item, dict):
            for key, value in current_item.items():
                if key == search_key:
                    yield value
                else:
                    stack.append(value)
        elif isinstance(current_item, list):
            for value in current_item:
                stack.append(value)


def main(url):
    df_comment = pd.DataFrame()
    try:
        youtube_url = url
        limit = COMMENT_LIMIT

        print('Downloading Youtube comments for video:', youtube_url)

        count = 0

        start_time = time.time()

        for comment in download_comments(youtube_url):

            df_comment = df_comment.append(comment, ignore_index=True)
#             df_comment = pd.concat([df_comment, comment], ignore_index=True)

            # comments overview
            comment_json = json.dumps(comment, ensure_ascii=False)
            print(comment_json)

            count += 1

            if limit and count >= limit:
                break

        print("DataFrame Shape: ",df_comment.shape,"\nComment DataFrame: ", df_comment)

        if not os.path.isfile(FILE_NAME):
            df_comment.to_csv(FILE_NAME, encoding='utf-8', index=False)
        else:  # else it exists so append without writing the header
            df_comment.to_csv(FILE_NAME, mode='a', encoding='utf-8', index=False, header=False)

        print('\n[{:.2f} seconds] Done!'.format(time.time() - start_time))

    except Exception as e:
        print('Error:', str(e))
        sys.exit(1)                            


# dumping youtube comments

""" 
1. Dump comments to a csv  from a single video

"""
# youtube_URL = 'https://www.youtube.com/watch?v=fucUDHaZ0Ug'
# main(youtube_URL)

"""
2. Dump comments to a csv by parsing links from a csv with video links

Example -
Create a csv with one column titled 'link'
a sample is given below

'ytb_video_list.csv'

link
https://www.youtube.com/watch?v=-t_uhBBDbA4
https://www.youtube.com/watch?v=75vjjRza7IU
https://www.youtube.com/watch?v=j6dmaPzOBHY
https://www.youtube.com/watch?v=Yj2efyQV1RI
https://www.youtube.com/watch?v=HV652F7U6Qs
https://www.youtube.com/watch?v=47iXEucg3eo
https://www.youtube.com/watch?v=ofHXBLEE3TQ
https://www.youtube.com/watch?v=X6lGqSfVRT8
https://www.youtube.com/watch?v=a_-z9FhGBrE
https://www.youtube.com/watch?v=wTUM_4cVlE4


"""
# df_video_list = pd.read_csv('ytb_video_list.csv')
# print(df_video_list['link'].map(lambda x: main(x)))
# print(main(pd.read_csv('ytb_video_list.csv')['link']))


"""
3. Dump to a csv from a a list with video links
"""
ytb_video_list = ['https://www.youtube.com/watch?v=jAMfmwMp2yk']

for video_link in ytb_video_list:
# {"cid": "UgzjrxwVE2EJManI_FF4AaABAg", "text": "Not only impressed but an amazing speech by the representative of Kenya, Well worded.", "time": "1 year ago", "author": "Fika Sionemale", "channel": "UCe3UmfcHrpB4YDtYgj7w3FQ", "votes": "202", "photo": "https://yt3.ggpht.com/ytc/AGIKgqOQCyvjpuFzIi2MG4gM4T3G0YCX_mR1_hbRrKgXWz_x2nhrrMzHpq1wCV8kbYks=s176-c-k-c0x00ffffff-no-rj", "heart": false}
# {"cid": "Ugz79et_s6cnyP7NaYN4AaABAg", "text": "Kenya's speech was world-class.  Timestamp: 41:00", "time": "1 year ago (edited)", "author": "Drugs are not cool", "channel": "UC_gXVp_OXwEqSEjWyedigeg", "votes": "818", "photo": "https://yt3.ggpht.com/ytc/AGIKgqNJRdmrGquJcArMAMlcAZByvS7ZajtGCVqDFGLO=s176-c-k-c0x00ffffff-no-rj", "heart": false}
# {"cid": "UgzSJEgMt3org2XzFLJ4AaABAg", "text": "Kenya to the 🌎 that was exactly what the world needed to hear.Proud of my country men", "time": "1 year ago", "author": "JAY RAPS", "channel": "UCLAjTyffGSxO_-a5LZpALQA", "votes": "60", "photo": "https://yt3.ggpht.com/WjcYZhof-igjXS5duIvTFSWXmPuqGRZiNMkunb9_dXZredYwIwz8v04RB4i33laiCYAJOR-JTw=s176-c-k-c0x00ffffff-no-rj", "heart": false}
# {"cid": "UgzVv0UPQOJYedH5Xmh4AaABAg", "text": "Amazing speech by Kenya", "time": "1 year ago", "author": "dejeffmcbob", "channel": "UCExoKgyYuJoD-_xZGMH5t1Q", "votes": "189", "photo": "https://yt3.ggpht.com/19Zr0HqVJ78HxeTTSVi-aXqvfcEjCoRJtrID50eIBXbQ2XAHVJAfcICnZi1XmBhbUJm-Ekx8isg=s176-c-k-c0x00ffffff-no-rj", "heart": false}
# {"cid": "UgzkV7rvm9MYFOct6MV4AaABAg", "text": "Thank You to the Representative for Kenya for the most Intelligent statement from this Meeting.", "time": "1 year ago", "author": "Ben Stutley", "channel": "UCg5EDBWO_UqLbAwDATA1dOw", "votes": "83", "photo": "https://yt3.ggpht.com/ytc/AGIKgqPycN3CajlwIeHiGa4G30ARqbv15S9EZf9TGSdub7jg7qMpbYGQTvRjCcvHFg3r=s176-c-k-c0x00ffffff-no-rj", "heart": false}
# {"cid": "Ugxx7TZTpBaPQGUQMYp4AaABAg", "text": "Kenya! The best The real speech The true  Go Ukraine👍", "time": "1 year ago", "author": "biok2006", "channel": "UCltN08I74UBiFvwoGPoTQRg", "votes": "107", "photo": "https://yt3.ggpht.com/ytc/AGIKgqMO4OLG9wqW43iRVTRv6cfEGhfHqpl_xBfNDt5d=s176-c-k-c0x00ffffff-no-rj", "heart": false}
# {"cid": "Ugzycsr-vHB2f_SMOQF4AaABAg", "text": "Thank you all for your efforts in trying to make the world a better place. Any country guilty of participating in abuses against humanity TO DATE lawfully shouldn't issue sanctions.", "time": "1 year ago", "author": "Kenna Marino", "channel": "UCjuiUWKCG9Glr-mHFiJWyeA", "votes": "1", "photo": "https://yt3.ggpht.com/ytc/AGIKgqMAVCP99gTPVcHanMkaTfwnJRMHKdMvRlOUYuw5bqdztIXOm3k44BkBRmazwPsQ=s176-c-k-c0x00ffffff-no-rj", "heart": false}
# {"cid": "UgxL9IVomM89VxZFxNt4AaABAg", "text": "Kenya's speech is very powerful! Thank you!", "time": "1 year ago (edited)", "author": "Maryna Koskela", "channel": "UC5hk9RT06ybbyGWq0bTEwjg", "votes": "34", "photo": "https://yt3.ggpht.com/ytc/AGIKgqO61URTfj0TKPrXIfMXuZQfoT_ENrY8HKVattpnTA=s176-c-k-c0x00ffffff-no-rj", "heart": false}
# {"cid": "Ugya2h09Kf4fEAPCyjx4AaABAg", "text": "LETS ALL PRAY FOR PEACE IN THE WORLD AND MAYBE THERE WILL BE PEACE IN THE FUTURE. ALL MY BLESS TO UKRAINE, from the Netherlands.", "time": "1 year ago", "author": "GTA ONLINE", "channel": "UCpOiT0GrOkynEqd2hmQPrdA", "votes": "63", "photo": "https://yt3.ggpht.com/ytc/AGIKgqO4ZGfLHzrCI_WrMfSzX8xpbj91fnnB49oivlJCFw=s176-c-k-c0x00ffffff-no-rj", "heart": false}
# {"cid": "UgzNYl4n4s4JAysNC0d4AaABAg", "text": "I loved Kenya speech.", "time": "1 year ago", "author": "DarkBrandon", "channel": "UCzM9QjmIFTKr3WiecESICcA", "votes": "81", "photo": "https://yt3.ggpht.com/YDJ5jrWKz8Qmfb7d0eC_AKAcr8n7MG3KH1zy39AN1BDHlWEnAv3XCy6S2AyDapumx53cgzgtzSo=s176-c-k-c0x00ffffff-no-rj", "heart": false}
# {"cid": "Ugz2VMeyEofoXKybVbF4AaABAg", "text": "Everyone talking about Kenya forgot about Albania's speech, where a very important question was asked \"Who is next?\"", "time": "1 year ago", "author": "Diogo Botelho", "channel": "UCgfwMlHxxmCW5jCFHmumqgQ", "votes": "107", "photo": "https://yt3.ggpht.com/ytc/AGIKgqN51XTjmdxh6z1aEg9yIwAVj17z7sVsURhBDZKS=s176-c-k-c0x00ffffff-no-rj", "heart": false}
# {"cid": "UgxFymxYIJ5N1pdEDJZ4AaABAg", "text": "This was the best council meeting if all time", "time": "1 year ago", "author": "VERTIGO ? : 10 years ago", "channel": "UCBEyte5Gkivky-DLm5JUAow", "votes": "11", "photo": "https://yt3.ggpht.com/zszCrE9ledBh5eUCNo_QZCxVJ-abNtCsQiWbEqANt5TK_6iYahOoziwQGmWNFlb38NfZKyDo=s176-c-k-c0x00ffffff-no-rj", "heart": false}
# {"cid": "Ugx2IExdCfKe13hSFoZ4AaABAg", "text": "Hats off to the Kenyan dude! I repeated his speech four times. Very professional and meaningful indeed!", "time": "1 year ago", "author": "LittleCaesar81", "channel": "UCff3pdwOZltlnc09Cw6GSzg", "votes": "4", "photo": "https://yt3.ggpht.com/ytc/AGIKgqM5M79g9TURI6HewK54d6AszbbI30RrUUq586n8Dw=s176-c-k-c0x00ffffff-no-rj", "heart": false}
# {"cid": "Ugw3T-RryhNWOlsRH2V4AaABAg", "text": "i am surprised on the speeches of Kenya and Brazil. Kenya for it's amazing  force and decisive words, giving a well deserved moral lesson to everyone on the room. Brazil for going against our blockheaded bureaucrats and asking both sides to calm down and not starting a firefight, a very different discourse than i was expecting to hear given the visit of Bolsonaro to Russia and Hungary and how negative the repercussion was.", "time": "1 year ago", "author": "marcossonicracer", "channel": "UC1ag8TMnxmwmCRlmfzjShAA", "votes": "21", "photo": "https://yt3.ggpht.com/ytc/AGIKgqPRCDfljKm9zxNiqQlIVbFavqZOddkkHxISh_Xp=s176-c-k-c0x00ffffff-no-rj", "heart": false}
# {"cid": "Ugya0CN8tovZnfReCH14AaABAg", "text": "I loved the British speech, it made me feel like I was back at school and about to take a beating from the Headmistress 😂", "time": "1 year ago", "author": "Arthur 242630", "channel": "UCNQZnDfPDOtMTGrXCnh1wTg", "votes": "42", "photo": "https://yt3.ggpht.com/ytc/AGIKgqPwSBWKi2u3PQRVRJp9ARG3rcq9msyE_C1N3Q=s176-c-k-c0x00ffffff-no-rj", "heart": false}
# DataFrame Shape:  (20, 8)
# Comment DataFrame:                             cid                                               text                 time                    author                   channel votes                                              photo  heart
# 0   UgzaQk_IjAEfWFQGp2Z4AaABAg  Timestamps: 1:16 - Meeting brief 6:34 - 🇺🇸 Uni...  1 year ago (edited)                    Squili  UC2S9xGMsj0aq8rvqJWSAsgA   723  https://yt3.ggpht.com/ytc/AGIKgqNMdHtlo4OGui9e...  False
# 1   UgxupmT8A9KrVpQh1gl4AaABAg  Kenya's speech was one of the most moving spee...  1 year ago (edited)              Marcus Grant  UCgM1LbXTWG_dbhoKz7fKkRw   285  https://yt3.ggpht.com/ytc/AGIKgqNwHPxyLNhqNoJ7...  False
# 2   UgzycO8XoOwbi5kUcRR4AaABAg  I am really impressed by the speech of the rep...           1 year ago               SleepWalker  UCExbzgi150m9hEqiqsJ9YtQ   642  https://yt3.ggpht.com/ytc/AGIKgqO4Y_SkkiotOKwA...  False
# 3   Ugw-379B-jbdSVLPLQZ4AaABAg  Continuously floored by the eloquence of the K...           1 year ago             Paulo Santana  UCfWE_setmUFOXaCIqoXGn1A   274  https://yt3.ggpht.com/ytc/AGIKgqMIWVpaZ54PsG-I...  False
# 4   UgyX0qpD3Gwf8lgMVfN4AaABAg  Can we all just give the Kenya representative ...           1 year ago               Patrick Poe  UCjska3QFuqx6-klYl_jtHtQ   242  https://yt3.ggpht.com/ytc/AGIKgqP8mgZcmAhsr2Yy...  False
# 5   UgzjrxwVE2EJManI_FF4AaABAg  Not only impressed but an amazing speech by th...           1 year ago            Fika Sionemale  UCe3UmfcHrpB4YDtYgj7w3FQ   202  https://yt3.ggpht.com/ytc/AGIKgqOQCyvjpuFzIi2M...  False
# 6   Ugz79et_s6cnyP7NaYN4AaABAg  Kenya's speech was world-class.  Timestamp: 41:00  1 year ago (edited)        Drugs are not cool  UC_gXVp_OXwEqSEjWyedigeg   818  https://yt3.ggpht.com/ytc/AGIKgqNJRdmrGquJcArM...  False
# 7   UgzSJEgMt3org2XzFLJ4AaABAg  Kenya to the 🌎 that was exactly what the world...           1 year ago                  JAY RAPS  UCLAjTyffGSxO_-a5LZpALQA    60  https://yt3.ggpht.com/WjcYZhof-igjXS5duIvTFSWX...  False
# 8   UgzVv0UPQOJYedH5Xmh4AaABAg                            Amazing speech by Kenya           1 year ago               dejeffmcbob  UCExoKgyYuJoD-_xZGMH5t1Q   189  https://yt3.ggpht.com/19Zr0HqVJ78HxeTTSVi-aXqv...  False
FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_comment = df_comment.append(comment, ignore_index=True)
# /var/folders/tj/57tjtnds1cxg93w1d0dcdhmr0000gn/T/ipykernel_27435/1655674201.py:152: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_comment = df_comment.append(comment, ignore_index=True)
# /var/folders/tj/57tjtnds1cxg93w1d0dcdhmr0000gn/T/ipykernel_27435/1655674201.py:152: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_comment = df_comment.append(comment, ignore_index=True)
# /var/folders/tj/57tjtnds1cxg93w1d0dcdhmr0000gn/T/ipykernel_27435/1655674201.py:152: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_comment = df_comment.append(comment, ignore_index=True)
# /var/folders/tj/57tjtnds1cxg93w1d0dcdhmr0000gn/T/ipykernel_27435/1655674201.py:152: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_comment = df_comment.append(comment, ignore_index=True)
# /var/folders/tj/57tjtnds1cxg93w1d0dcdhmr0000gn/T/ipykernel_27435/1655674201.py:152: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_comment = df_comment.append(comment, ignore_index=True)
# /var/folders/tj/57tjtnds1cxg93w1d0dcdhmr0000gn/T/ipykernel_27435/1655674201.py:152: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_comment = df_comment.append(comment, ignore_index=True)
# /var/folders/tj/57tjtnds1cxg93w1d0dcdhmr0000gn/T/ipykernel_27435/1655674201.py:152: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_comment = df_comment.append(comment, ignore_index=True)
# /var/folders/tj/57tjtnds1cxg93w1d0dcdhmr0000gn/T/ipykernel_27435/1655674201.py:152: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_comment = df_comment.append(comment, ignore_index=True)
# /var/folders/tj/57tjtnds1cxg93w1d0dcdhmr0000gn/T/ipykernel_27435/1655674201.py:152: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_comment = df_comment.append(comment, ignore_index=True)
# /var/folders/tj/57tjtnds1cxg93w1d0dcdhmr0000gn/T/ipykernel_27435/1655674201.py:152: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_comment = df_comment.append(comment, ignore_index=True)
# /var/folders/tj/57tjtnds1cxg93w1d0dcdhmr0000gn/T/ipykernel_27435/1655674201.py:152: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_comment = df_comment.append(comment, ignore_index=True)
# /var/folders/tj/57tjtnds1cxg93w1d0dcdhmr0000gn/T/ipykernel_27435/1655674201.py:152: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_comment = df_comment.append(comment, ignore_index=True)
# /var/folders/tj/57tjtnds1cxg93w1d0dcdhmr0000gn/T/ipykernel_27435/1655674201.py:152: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_comment = df_comment.append(comment, ignore_index=True)
# /var/folders/tj/57tjtnds1cxg93w1d0dcdhmr0000gn/T/ipykernel_27435/1655674201.py:152: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_comment = df_comment.append(comment, ignore_index=True)
# /var/folders/tj/57tjtnds1cxg93w1d0dcdhmr0000gn/T/ipykernel_27435/1655674201.py:152: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_comment = df_comment.append(comment, ignore_index=True)
# /var/folders/tj/57tjtnds1cxg93w1d0dcdhmr0000gn/T/ipykernel_27435/1655674201.py:152: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_comment = df_comment.append(comment, ignore_index=True)
# /var/folders/tj/57tjtnds1cxg93w1d0dcdhmr0000gn/T/ipykernel_27435/1655674201.py:152: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_comment = df_comment.append(comment, ignore_index=True)
# /var/folders/tj/57tjtnds1cxg93w1d0dcdhmr0000gn/T/ipykernel_27435/1655674201.py:152: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_comment = df_comment.append(comment, ignore_index=True)
# /var/folders/tj/57tjtnds1cxg93w1d0dcdhmr0000gn/T/ipykernel_27435/1655674201.py:152: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_comment = df_comment.append(comment, ignore_index=True)

# %%
df_comment = pd.read_csv('ytb_comments.csv')
df_comment.shape
# Out:
# (20, 8)
